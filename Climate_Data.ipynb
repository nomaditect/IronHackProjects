# %%
import pandas as pd

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('/Users/AFROARC/Documents/GitHub/class_labs_assignment/Air_Pollution_data_analysis/Large_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368005 entries, 0 to 1368004
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   CountryOrTerritory       1368005 non-null  object
#  1   ReportingYear            1368005 non-null  int64
#  2   UpdateTime               1368005 non-null  object
#  3   StationLocalId           1368005 non-null  object
#  4   SamplingPointLocalId     1368005 non-null  object
#  5   SamplingPoint_Latitude   1368005 non-null  float64
#  6   SamplingPoint_Longitude  1368005 non-null  float64
#  7   Pollutant                1368005 non-null  object
#  8   AggregationType          1368005 non-null  object
#  9   Namespace                1368005 non-null  object
#  10  Unit                     1368005 non-null  object
#  11  BeginPosition            1368005 non-null  object
#  12  EndPosition              1368005 non-null  object
# ...

# %%
df.head()
# Out:
#   CountryOrTerritory  ReportingYear                   UpdateTime  \
# 0            Austria           2014  2020-07-17T12:48:22.713333Z
# 1            Austria           2014  2020-07-17T12:48:22.713333Z
# 2            Austria           2014  2020-07-17T12:48:22.713333Z
# 3            Austria           2014  2020-07-17T12:48:22.713333Z
# 4            Austria           2014  2020-07-17T12:48:22.713333Z
#
#   StationLocalId   SamplingPointLocalId  SamplingPoint_Latitude  \
# 0    STA.04.S406   SPO.04.S406.5058.5.1               48.165000
# 1     STA.06.195   SPO.06.195.56371.5.1               46.813889
# 2    STA.07.2227  SPO.07.2227.56410.5.1               47.278070
# 3    STA.08.1919   SPO.08.1919.4955.5.1               47.239445
# 4    STA.09.KEND  SPO.09.KEND.55196.5.1               48.205000
#
#    SamplingPoint_Longitude                             Pollutant  \
# 0                14.035556  Particulate matter < 10 µm (aerosol)
# ...

# %%
#sns.pairplot(df)

# %%
dfnum = df.select_dtypes([np.number])
dfnum.columns.to_list()
# Out:
# ['ReportingYear',
#  'SamplingPoint_Latitude',
#  'SamplingPoint_Longitude',
#  'DataCoverage',
#  'DataCapture',
#  'TimeCoverage',
#  'AQValue']

# %%
dfnum.head()
# Out:
#    ReportingYear  SamplingPoint_Latitude  SamplingPoint_Longitude  \
# 0           2014               48.165000                14.035556
# 1           2014               46.813889                15.212778
# 2           2014               47.278070                11.512497
# 3           2014               47.239445                 9.597696
# 4           2014               48.205000                16.309750
#
#    DataCoverage  DataCapture  TimeCoverage    AQValue
# 0    100.000000        100.0    100.000000  41.000000
# 1     99.726027        100.0     99.726027  32.400002
# 2     99.726027        100.0     99.726027  33.785000
# 3     99.726027        100.0     99.726027  30.000000
# 4     99.452055        100.0     99.452055  42.656990
